# %%
import pandas as pd
unkai_df = pd.read_csv("./雲海2014.csv", header=1)
unkai_df.head()
# Out:
#           日付   出現  確率 閾値40 閾値50 閾値60
# 0  2014/5/17  0.0  20   適中   適中   適中
# 1  2014/5/18  0.0  30   適中   適中   適中
# 2  2014/5/19  0.0  40  空振り   適中   適中
# 3  2014/5/20  0.0  40  空振り   適中   適中
# 4  2014/5/21  0.0  50  空振り  空振り   適中

# %%
target_df = unkai_df.loc[unkai_df["閾値40"] == "適中"]
target_df.head()
# Out:
#            日付   出現  確率 閾値40 閾値50 閾値60
# 0   2014/5/17  0.0  20   適中   適中   適中
# 1   2014/5/18  0.0  30   適中   適中   適中
# 6   2014/5/23  1.0  40   適中  見逃し  見逃し
# 7   2014/5/24  1.0  50   適中   適中  見逃し
# 11  2014/5/28  1.0  60   適中   適中   適中

# %%
target_dates = target_df["日付"].to_numpy()
target_dates
# Out:
# array(['2014/5/17', '2014/5/18', '2014/5/23', '2014/5/24', '2014/5/28',
#        '2014/5/31', '2014/6/3', '2014/6/6', '2014/6/7', '2014/6/8',
#        '2014/6/9', '2014/6/10', '2014/6/11', '2014/6/12', '2014/6/13',
#        '2014/6/18', '2014/6/19', '2014/6/20', '2014/6/22', '2014/6/23',
#        '2014/6/24', '2014/6/25', '2014/6/26', '2014/6/27', '2014/6/28',
#        '2014/7/1', '2014/7/6', '2014/7/7', '2014/7/8', '2014/7/9',
#        '2014/7/10', '2014/7/14', '2014/7/16', '2014/7/17', '2014/7/18',
#        '2014/7/22', '2014/7/23', '2014/7/24', '2014/7/28', '2014/7/29',
#        '2014/7/30', '2014/8/2', '2014/8/3', '2014/8/9', '2014/8/10',
#        '2014/8/15', '2014/8/16', '2014/8/17', '2014/8/18', '2014/8/19',
#        '2014/8/23', '2014/8/24', '2014/8/27', '2014/8/29', '2014/8/30',
#        '2014/8/31', '2014/9/1', '2014/9/2', '2014/9/3', '2014/9/7',
#        '2014/9/10', '2014/9/11', '2014/9/12', '2014/9/13', '2014/9/14',
#        '2014/9/15', '2014/9/17', '2014/9/18', '2014/9/21', '2014/9/22',
#        '2014/9/23', '2014/9/24', '2014/9/25', '2014/9/26', '2014/9/28',
#        '2014/9/29', '2014/9/30', '2014/10/3', '2014/10/4', '2014/10/7',
#        '2014/10/9', '2014/10/12', '2014/10/24'], dtype=object)

# %%
def inquire_grib_data(path):
    import pygrib                  # gribファイルの中身を見たい場合はinquire_grib_data(path)を実行                
    grbs = pygrib.open(path)
    for grb in grbs:
        print(grb)
    return
def read_grib_data(path,name=None,level=None):
    import numpy as np
    import pygrib                   # pygribは!pip3 install pygrib --userでインストール
    grbs = pygrib.open(path)

    if name != None:                # anl_surf125に対しては変数名を与える
        alines = grbs.select(name=name)
    elif level != None:             # anl_p125に対しては気圧面を与えるとその水平面データ
        alines = grbs.select(level=level)
    else:                           #                  気圧面を与えないと全３次元データ
        alines = grbs.select()

    lat, lon = alines[0].latlons()  # lonは経度、latは緯度データ: (ny,nx)の２次元格子です
    ny, nx = lat.shape
    nline = len(alines)
    gdata = np.empty( (nline,ny,nx), dtype = "f4" )
    levels = np.empty( (nline), dtype = "f4" )
    for iline, aline in enumerate(alines):
        gdata[iline,:,:] = aline.values[::-1,:]
        levels[iline] = aline["level"]

    return lon, lat[::-1], level, gdata

# %%
import datetime as dt
import calendar as cal
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

dts=[]
for m in range(12):
    month=m+1
    nmonth=cal.monthrange(2014,month)[1]
    dts.extend([dt.datetime(2014,month,1,0)+dt.timedelta(hours=6*i) for i in range(nmonth*4)])  #一年分の平均

for i,dt in enumerate(dts):
    fdir = "/mnt/hwmet-hdd01/Database/JRA55/anl_p125/"
    fname = "/anl_surf125."
    path=dt.strftime(fdir+"%Y%m"+fname+"%Y%m%d%H")

target_idxes = []
for idx, d in enumerate(dts):
    string_dt = f"{d.year}/{d.month}/{d.day}"
    if string_dt in target_dates:
#         print(idx, string_dt)
        target_idxes.append(idx)
    
print(target_idxes)
# Out:
# [544, 545, 546, 547, 548, 549, 550, 551, 568, 569, 570, 571, 572, 573, 574, 575, 588, 589, 590, 591, 600, 601, 602, 603, 612, 613, 614, 615, 624, 625, 626, 627, 628, 629, 630, 631, 632, 633, 634, 635, 636, 637, 638, 639, 640, 641, 642, 643, 644, 645, 646, 647, 648, 649, 650, 651, 652, 653, 654, 655, 672, 673, 674, 675, 676, 677, 678, 679, 680, 681, 682, 683, 688, 689, 690, 691, 692, 693, 694, 695, 696, 697, 698, 699, 700, 701, 702, 703, 704, 705, 706, 707, 708, 709, 710, 711, 712, 713, 714, 715, 724, 725, 726, 727, 744, 745, 746, 747, 748, 749, 750, 751, 752, 753, 754, 755, 756, 757, 758, 759, 760, 761, 762, 763, 776, 777, 778, 779, 784, 785, 786, 787, 788, 789, 790, 791, 792, 793, 794, 795, 808, 809, 810, 811, 812, 813, 814, 815, 816, 817, 818, 819, 832, 833, 834, 835, 836, 837, 838, 839, 840, 841, 842, 843, 852, 853, 854, 855, 856, 857, 858, 859, 880, 881, 882, 883, 884, 885, 886, 887, 904, 905, 906, 907, 908, 909, 910, 911, 912, 913, 914, 915, 916, 917, 918, 919, 920, 921, 922, 923, 936, 937, 938, 939, 940, 941, 942, 943, 952, 953, 954, 955, 960, 961, 962, 963, 964, 965, 966, 967, 968, 969, 970, 971, 972, 973, 974, 975, 976, 977, 978, 979, 980, 981, 982, 983, 996, 997, 998, 999, 1008, 1009, 1010, 1011, 1012, 1013, 1014, 1015, 1016, 1017, 1018, 1019, 1020, 1021, 1022, 1023, 1024, 1025, 1026, 1027, 1028, 1029, 1030, 1031, 1036, 1037, 1038, 1039, 1040, 1041, 1042, 1043, 1052, 1053, 1054, 1055, 1056, 1057, 1058, 1059, 1060, 1061, 1062, 1063, 1064, 1065, 1066, 1067, 1068, 1069, 1070, 1071, 1072, 1073, 1074, 1075, 1080, 1081, 1082, 1083, 1084, 1085, 1086, 1087, 1088, 1089, 1090, 1091, 1100, 1101, 1102, 1103, 1104, 1105, 1106, 1107, 1116, 1117, 1118, 1119, 1124, 1125, 1126, 1127, 1136, 1137, 1138, 1139, 1184, 1185, 1186, 1187]

# %%
mean = np.mean(slpm[target_idxes, :, :], axis=0)
mean
