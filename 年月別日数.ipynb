# %%
import numpy as np
import matplotlib.pyplot as plt
import japanize_matplotlib
import openpyxl
import pandas as pd
import matplotlib.dates as mdates
import numpy as np
import matplotlib.pyplot as plt
import japanize_matplotlib
import openpyxl
import pandas as pd
import matplotlib.dates as mdates

fig = plt.figure(figsize=(20, 10))
ax1 = fig.subplots()
#ax2 = ax1.twinx()

df = pd.read_csv("78月.csv")
#df = df_2012
df.head()
a = df['年'].values
b = df['7月'].values
c = df['8月'].values
#ax1.plot(a,b,color='r',marker="*",linestyle="None")
ax1.plot(a,b,color='r',marker="o",label='7月')
ax1.plot(a,c,color='b',marker="o",label='8月')
ax1.legend()
ax1.set_ylim([0,20])
ax1.set_title("7,8月霧日数")
ax1.set_xlabel(df['年'].name)
ax1.set_ylabel("霧日数")
plt.yticks([0, 5, 10, 15, 20, 21])
plt.xticks([2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021])
plt.rcParams["font.size"] = 25

plt.grid(True)
#plt.gca().xaxis.set_major_locator(mdates.YearLocator(interval=1))
#plt.gca().xaxis.set_major_locator(mdates.YearLocator())
#fig.autofmt_xdate(rotation=45)
plt.savefig("雲海月日数7月.png")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import japanize_matplotlib
import openpyxl
import pandas as pd
import matplotlib.dates as mdates
import numpy as np
import matplotlib.pyplot as plt
import japanize_matplotlib
import openpyxl
import pandas as pd
import matplotlib.dates as mdates

fig = plt.figure(figsize=(20, 10))
ax1 = fig.subplots()
#ax2 = ax1.twinx()

df = pd.read_csv("78月.csv")
#df = df_2012
df.head()
a = df['年'].values
b = df['8月'].values
#ax1.plot(a,b,color='r',marker="*",linestyle="None")
ax1.plot(a,b,color='r',marker="o")
ax1.set_ylim([0,20])
ax1.set_title("8月霧日数")
ax1.set_xlabel(df['年'].name)
ax1.set_ylabel("霧日数")
# start, end = ax1.get_ylim()
# stepsize=5
# ax1.yaxis.set_ticks(pd.np.arange(start, end, stepsize))
plt.yticks([0, 5, 10, 15, 20])
plt.xticks([2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021])
plt.rcParams["font.size"] = 20


plt.grid(True)
#plt.gca().xaxis.set_major_locator(mdates.YearLocator(interval=1))
#plt.gca().xaxis.set_major_locator(mdates.YearLocator())
#fig.autofmt_xdate(rotation=45)
plt.savefig("雲海月日数8月.png")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import japanize_matplotlib
import openpyxl
import pandas as pd
import matplotlib.dates as mdates
import numpy as np
import matplotlib.pyplot as plt
import japanize_matplotlib
import openpyxl
import pandas as pd
import matplotlib.dates as mdates

fig = plt.figure(figsize=(20, 10))
ax1 = fig.subplots()
#ax2 = ax1.twinx()

df = pd.read_csv("雲海年日数.csv")
#df = df_2012
df.head()
a = df['年'].values
b = df['日数'].values
#ax1.plot(a,b,color='r',marker="*",linestyle="None")
ax1.plot(a,b,color='r',marker="o")
ax1.set_title("年別雲海出現日数")
ax1.set_ylim([0,80])
ax1.set_ylabel(df['日数'].name)
ax1.set_xlabel(df['年'].name)
plt.xticks([2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021])
plt.rcParams["font.size"] = 20

plt.grid(True)
#plt.gca().xaxis.set_major_locator(mdates.YearLocator(interval=1))
#plt.gca().xaxis.set_major_locator(mdates.YearLocator())
#fig.autofmt_xdate(rotation=45)
plt.savefig("年別雲海出現日数.png")
plt.show()
